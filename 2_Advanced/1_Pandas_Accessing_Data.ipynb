# %%
# Importing Libraries
import ast
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datasets import load_dataset

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
# Out:
# Found cached dataset csv (/Users/aref/.cache/huggingface/datasets/lukebarousse___csv/lukebarousse--data_jobs-8492436fa5796c3e/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df.sample(20)
# Out:
#              job_title_short  \
# 646717  Senior Data Engineer
# 435796        Data Scientist
# 115988          Data Analyst
# 566179          Data Analyst
# 345640        Data Scientist
# 317583          Data Analyst
# 562069        Data Scientist
# 345516        Data Scientist
# 732722         Data Engineer
# 183172         Data Engineer
# 35881      Software Engineer
# 152513     Software Engineer
# 283045        Cloud Engineer
# 658729         Data Engineer
# 698684        Data Scientist
# 430509         Data Engineer
# 56622          Data Engineer
# 687257        Data Scientist
# 427540  Senior Data Engineer
# 304230      Business Analyst
#
#                                                 job_title  \
# 646717                               Senior Data Engineer
# 435796                                     Data Scientist
# 115988  eDiscovery Structured Data Analyst - Assistant...
# 566179                   Junior BI Developer/Data Analyst
# 345640                                     DATA SCIENTIST
# 317583                                       Data Analyst
# 562069                    Data Science Manager, Investing
# 345516                                 Analytics Engineer
# 732722                                      Data Engineer
# 183172                                      Data Engineer
# 35881                                   Software Engineer
# 152513                        Software- und Data Engineer
# 283045                               Cloud Engineer Azure
# 658729  Data engineer with Snowflake :: California or ...
# 698684                                    Process Analyst
# 430509                         Data Integration Developer
# 56622                                 Azure Data Engineer
# 687257                          Data Scientist, Analytics
# 427540                               Sr Big Data Engineer
# 304230               Analyst - Business Reporting at Sama
#
#                                              job_location  \
# 646717                                  Budapest, Hungary
# 435796                                   Philadelphia, PA
# 115988                                   Jacksonville, FL
# 566179                                   Lisbon, Portugal
# 345640                                      Paris, France
# 317583                                     Nairobi, Kenya
# 562069                                             Canada
# 345516                                           Anywhere
# 732722  Mendoza, Capital Department, Mendoza Province,...
# 183172                                  West Midlands, UK
# 35881       Vilnius, Vilnius City Municipality, Lithuania
# 152513                                   Cologne, Germany
# 283045                                         Lima, Peru
# 658729                                           Anywhere
# 698684                                    Dublin, Ireland
# 430509                               Waterloo, ON, Canada
# 56622                            Jaipur, Rajasthan, India
# 687257                                      Palo Alto, CA
# 427540                                           Anywhere
# 304230                                     Nairobi, Kenya
#
#                                               job_via job_schedule_type  \
# 646717                           via LinkedIn Hungary         Full-time
# 435796                                     via Indeed         Full-time
# 115988                                    via Ladders         Full-time
# 566179                             via BeBee Portugal         Full-time
# 345640                                via Recruit.net         Full-time
# 317583                                via BeBee Kenya         Full-time
# 562069                               via BeBee Canada         Full-time
# 345516                                  via BEAMSTART         Full-time
# 732722                                      via BeBee         Full-time
# 183172                           via MyArklaMiss Jobs        Contractor
# 35881                                 via Trabajo.org         Full-time
# 152513                                      via BeBee         Full-time
# 283045  via Trabajo.org - Vacantes De Empleo, Trabajo         Full-time
# 658729                                   via LinkedIn         Full-time
# 698684                                via Trabajo.org         Full-time
# 430509                               via BeBee Canada         Full-time
# 56622                                    via LinkedIn         Full-time
# 687257                                   via The Muse         Full-time
# 427540                                   via LinkedIn        Contractor
# 304230                                via Trabajo.org         Full-time
#
#         job_work_from_home            search_location     job_posted_date  \
# 646717               False                    Hungary 2023-08-22 12:18:45
# 435796               False    New York, United States 2023-05-30 16:02:18
# 115988               False     Florida, United States 2023-10-11 08:02:12
# 566179               False                   Portugal 2023-01-21 05:09:39
# 345640               False                     France 2023-07-18 00:05:52
# 317583               False                      Kenya 2023-05-26 17:26:47
# 562069               False                     Canada 2023-08-26 04:23:48
# 345516                True                     Mexico 2023-02-22 23:41:34
# 732722               False                  Argentina 2023-01-24 21:27:11
# 183172               False             United Kingdom 2023-08-22 15:16:19
# 35881                False                  Lithuania 2023-03-17 13:47:00
# 152513               False                    Germany 2023-12-15 08:33:16
# 283045               False                       Peru 2023-07-29 07:10:48
# 658729                True                    Georgia 2023-08-04 11:02:08
# 698684               False                    Ireland 2023-06-02 04:23:39
# 430509               False                     Canada 2023-01-22 16:15:55
# 56622                False                      India 2023-05-05 06:30:38
# 687257               False  California, United States 2023-01-26 10:05:24
# 427540                True    Illinois, United States 2023-03-23 16:15:21
# 304230               False                      Kenya 2023-07-05 17:22:07
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 646717                  False                 False         Hungary
# 435796                  False                  True   United States
# 115988                  False                  True   United States
# 566179                   True                 False        Portugal
# 345640                  False                 False          France
# 317583                  False                 False           Kenya
# 562069                  False                 False          Canada
# 345516                   True                 False          Mexico
# 732722                  False                 False       Argentina
# 183172                   True                 False  United Kingdom
# 35881                    True                 False       Lithuania
# 152513                   True                 False         Germany
# 283045                  False                 False            Peru
# 658729                   True                 False   United States
# 698684                  False                 False         Ireland
# 430509                  False                 False          Canada
# 56622                   False                 False           India
# 687257                  False                  True   United States
# 427540                   True                 False   United States
# 304230                  False                 False           Kenya
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 646717        None              NaN              NaN
# 435796        year         101500.0              NaN
# 115988        year          94000.0              NaN
# 566179        None              NaN              NaN
# 345640        None              NaN              NaN
# 317583        None              NaN              NaN
# 562069        None              NaN              NaN
# 345516        None              NaN              NaN
# 732722        None              NaN              NaN
# 183172        None              NaN              NaN
# 35881         None              NaN              NaN
# 152513        None              NaN              NaN
# 283045        None              NaN              NaN
# 658729        None              NaN              NaN
# 698684        None              NaN              NaN
# 430509        None              NaN              NaN
# 56622         None              NaN              NaN
# 687257        None              NaN              NaN
# 427540        None              NaN              NaN
# 304230        None              NaN              NaN
#
#                             company_name  \
# 646717                    Morgan Stanley
# 435796           Chubb INA Holdings Inc.
# 115988                     Deutsche Bank
# 566179               Spring Professional
# 345640                       Wearemobius
# 317583                              AECF
# 562069                      Wealthsimple
# 345516                                R2
# 732722                            Wakapi
# 183172                         Investigo
# 35881   Danske Bank AS Lietuvos filialas
# 152513                      envelio GmbH
# 283045                           Emprego
# 658729                              Dice
# 698684                               CPL
# 430509                       KPMG Canada
# 56622                         Kadel Labs
# 687257                    NEXT Insurance
# 427540                   The Judge Group
# 304230                              Sama
#
#                                                job_skills  \
# 646717  ['python', 'sql', 'scala', 'java', 'snowflake'...
# 435796     ['python', 'r', 'sql', 'databricks', 'github']
# 115988                                   ['sql', 'excel']
# 566179                            ['sql', 'vba', 'excel']
# 345640                                               None
# 317583                                               None
# 562069  ['python', 'sql', 'pandas', 'scikit-learn', 'n...
# 345516          ['go', 'sql', 'python', 'aws', 'tableau']
# 732722  ['python', 'java', 'scala', 'sql', 'nosql', 'm...
# 183172                                          ['azure']
# 35881                                            ['java']
# 152513                           ['python', 'postgresql']
# 283045  ['sql', 'powershell', 'bash', 'c', 'express', ...
# 658729  ['sql', 'java', 'python', 'sql server', 'snowf...
# 698684                                               None
# 430509  ['python', 'sql', 't-sql', 'java', 'sql server...
# 56622   ['sql', 'python', 'sql server', 'azure', 'pysp...
# 687257                                  ['sql', 'python']
# 427540  ['python', 'azure', 'aws', 'gcp', 'spark', 'ha...
# 304230              ['sql', 'looker', 'tableau', 'excel']
#
#                                           job_type_skills
# 646717  {'cloud': ['snowflake', 'databricks'], 'other'...
# 435796  {'cloud': ['databricks'], 'other': ['github'],...
# 115988  {'analyst_tools': ['excel'], 'programming': ['...
# 566179  {'analyst_tools': ['excel'], 'programming': ['...
# 345640                                               None
# 317583                                               None
# 562069  {'libraries': ['pandas', 'scikit-learn', 'nump...
# 345516  {'analyst_tools': ['tableau'], 'cloud': ['aws'...
# 732722  {'cloud': ['aws'], 'databases': ['mysql'], 'pr...
# 183172                               {'cloud': ['azure']}
# 35881                           {'programming': ['java']}
# 152513  {'databases': ['postgresql'], 'programming': [...
# 283045  {'other': ['kubernetes', 'docker', 'terraform'...
# 658729  {'analyst_tools': ['ssis'], 'cloud': ['snowfla...
# 698684                                               None
# 430509  {'analyst_tools': ['ssis', 'sharepoint'], 'asy...
# 56622   {'cloud': ['azure'], 'databases': ['sql server...
# 687257                 {'programming': ['sql', 'python']}
# 427540  {'cloud': ['azure', 'aws', 'gcp'], 'libraries'...
# 304230  {'analyst_tools': ['looker', 'tableau', 'excel...

# %%
x = df.loc[:, 'salary_rate':]
x.dropna(subset = ['salary_year_avg', 'salary_hour_avg', 'company_name'])
# Out:
# Empty DataFrame
# Columns: [salary_rate, salary_year_avg, salary_hour_avg, company_name, job_skills, job_type_skills]
# Index: []
